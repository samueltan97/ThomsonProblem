# %%
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.animation as ani
import matplotlib.cm as cm 
from threading import Thread
from time import sleep
from main import MainCycle
# particle as particle




# allows animation features within notebook
# %matplotlib notebook

# %%
cycle = MainCycle(200,0.01)
cycle.start_cycle(50)
#print(cycle.particle_list[0].total_potential_energy)

# %%
fig, ax1 = plt.subplots(1, figsize=(8,8))


ax1.plot(cycle.counter, cycle.total_potential_energy)
ax1.grid()

print(cycle.total_potential_energy[-1])
print(np.shape(cycle.counter))
print(np.shape(cycle.total_potential_energy))
# Out:
# <img src="data:image/png;base64,..." width="800">
# 0.5169762230495675
# (103,)
# (103,)
